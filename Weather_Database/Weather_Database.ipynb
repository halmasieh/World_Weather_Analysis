# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy
# Use the tuple() function to display the latitude and longitude combinations.
for coordinate in coordinates:
    print(citipy.nearest_city(coordinate[0], coordinate[1]).city_name,
          citipy.nearest_city(coordinate[0], coordinate[1]).country_code)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 740

# %%
import requests
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
# print(url)

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
print(city_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7ed9371a15d2eed768ae74f693e57787&q=Boston

# %%
city_res = requests.get(city_url)
city_res.json()
# Out:
# {'coord': {'lon': -71.0598, 'lat': 42.3584},
#  'weather': [{'id': 801,
#    'main': 'Clouds',
#    'description': 'few clouds',
#    'icon': '02d'}],
#  'base': 'stations',
#  'main': {'temp': 36.95,
#   'feels_like': 26.37,
#   'temp_min': 35.01,
#   'temp_max': 39,
#   'pressure': 1014,
#   'humidity': 51},
#  'visibility': 10000,
#  'wind': {'speed': 10, 'deg': 273, 'gust': 21},
#  'clouds': {'all': 18},
#  'dt': 1612625725,
#  'sys': {'type': 3,
#   'id': 2013408,
#   'country': 'US',
#   'sunrise': 1612612326,
#   'sunset': 1612649077},
#  'timezone': -18000,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
city_info = city_res.json()

# %%
lat = city_info["coord"]["lat"]
lng = city_info["coord"]["lon"]
max_temp = city_info["main"]["temp_max"]
humidity = city_info["main"]["humidity"]
clouds = city_info["clouds"]["all"]
wind = city_info["wind"]["speed"]
weather_des = city_info["weather"][0]["description"]
print(lat, lng, max_temp, humidity, clouds, wind, weather_des)
# Out:
# 42.3584 -71.0598 39 51 18 10 few clouds

# %%
# Import the datetime module from the datetime library.
from datetime import datetime
#Get the date from the JSON file.
#date = city_info["dt"]
#Convert the UTC date to a date format with year, month, day, hours, minutes, and seconds.
#datetime.utcfromtimestamp(date)

# %%
#datetime.utcfromtimestamp(date).strftime("%Y-%m-%d %H:%M:%S")

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_des = city_weather["weather"][0]["description"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_des})
                          
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | hilo
# Processing Record 2 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 3 of Set 1 | henties bay
# Processing Record 4 of Set 1 | bengkulu
# Processing Record 5 of Set 1 | jining
# Processing Record 6 of Set 1 | albany
# Processing Record 7 of Set 1 | saint-philippe
# Processing Record 8 of Set 1 | bluff
# Processing Record 9 of Set 1 | avarua
# Processing Record 10 of Set 1 | saint-augustin
# Processing Record 11 of Set 1 | marzuq
# Processing Record 12 of Set 1 | atuona
# Processing Record 13 of Set 1 | rikitea
# Processing Record 14 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 15 of Set 1 | kotdwara
# Processing Record 16 of Set 1 | mataura
# Processing Record 17 of Set 1 | okha
# Processing Record 18 of Set 1 | provideniya
# Processing Record 19 of Set 1 | kostino
# Processing Record 20 of Set 1 | yulara
# Processing Record 21 of Set 1 | guerrero negro
# Processing Record 22 of Set 1 | victoria
# Processing Record 23 of Set 1 | hermanus
# Processing Record 24 of Set 1 | ushuaia
# Processing Record 25 of Set 1 | chimore
# Processing Record 26 of Set 1 | tuktoyaktuk
# Processing Record 27 of Set 1 | yatou
# Processing Record 28 of Set 1 | am timan
# Processing Record 29 of Set 1 | jamestown
# Processing Record 30 of Set 1 | pisco
# Processing Record 31 of Set 1 | yellowknife
# Processing Record 32 of Set 1 | broken hill
# Processing Record 33 of Set 1 | hobart
# Processing Record 34 of Set 1 | rio grande
# Processing Record 35 of Set 1 | ponta do sol
# Processing Record 36 of Set 1 | decatur
# Processing Record 37 of Set 1 | shenjiamen
# Processing Record 38 of Set 1 | bontang
# Processing Record 39 of Set 1 | namtsy
# Processing Record 40 of Set 1 | dikson
# Processing Record 41 of Set 1 | agapovka
# Processing Record 42 of Set 1 | punta arenas
# Processing Record 43 of Set 1 | vaini
# Processing Record 44 of Set 1 | saint george
# Processing Record 45 of Set 1 | hasaki
# Processing Record 46 of Set 1 | leningradskiy
# Processing Record 47 of Set 1 | bambous virieux
# Processing Record 48 of Set 1 | castro
# Processing Record 49 of Set 1 | ashtabula
# Processing Record 50 of Set 1 | arraial do cabo
# Processing Record 1 of Set 2 | bethel
# Processing Record 2 of Set 2 | khatanga
# Processing Record 3 of Set 2 | yaan
# Processing Record 4 of Set 2 | qaqortoq
# Processing Record 5 of Set 2 | tshikapa
# Processing Record 6 of Set 2 | port alfred
# Processing Record 7 of Set 2 | mar del plata
# Processing Record 8 of Set 2 | puerto ayora
# Processing Record 9 of Set 2 | hithadhoo
# Processing Record 10 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 11 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 12 of Set 2 | ancud
# Processing Record 13 of Set 2 | nanortalik
# Processing Record 14 of Set 2 | arman
# Processing Record 15 of Set 2 | gelemso
# Processing Record 16 of Set 2 | chapais
# Processing Record 17 of Set 2 | benguela
# Processing Record 18 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 19 of Set 2 | saskylakh
# Processing Record 20 of Set 2 | rawson
# Processing Record 21 of Set 2 | yuzhno-kurilsk
# Processing Record 22 of Set 2 | chuy
# Processing Record 23 of Set 2 | lichinga
# Processing Record 24 of Set 2 | butaritari
# Processing Record 25 of Set 2 | presidencia roque saenz pena
# Processing Record 26 of Set 2 | te anau
# Processing Record 27 of Set 2 | norman wells
# Processing Record 28 of Set 2 | kodiak
# Processing Record 29 of Set 2 | tual
# Processing Record 30 of Set 2 | trairi
# Processing Record 31 of Set 2 | brae
# Processing Record 32 of Set 2 | agstafa
# City not found. Skipping...
# Processing Record 33 of Set 2 | georgetown
# Processing Record 34 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 35 of Set 2 | dustlik
# Processing Record 36 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 37 of Set 2 | tessalit
# Processing Record 38 of Set 2 | prabumulih
# Processing Record 39 of Set 2 | shakawe
# Processing Record 40 of Set 2 | mrirt
# City not found. Skipping...
# Processing Record 41 of Set 2 | wuwei
# Processing Record 42 of Set 2 | qaanaaq
# Processing Record 43 of Set 2 | vrangel
# Processing Record 44 of Set 2 | busselton
# Processing Record 45 of Set 2 | codrington
# Processing Record 46 of Set 2 | komsomolskiy
# Processing Record 47 of Set 2 | alotau
# City not found. Skipping...
# Processing Record 48 of Set 2 | los llanos de aridane
# Processing Record 49 of Set 2 | cabo san lucas
# Processing Record 50 of Set 2 | develi
# Processing Record 1 of Set 3 | novikovo
# Processing Record 2 of Set 3 | narsaq
# Processing Record 3 of Set 3 | cape town
# Processing Record 4 of Set 3 | pacific grove
# Processing Record 5 of Set 3 | beringovskiy
# Processing Record 6 of Set 3 | jalu
# Processing Record 7 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 8 of Set 3 | sawakin
# Processing Record 9 of Set 3 | mahebourg
# Processing Record 10 of Set 3 | kapaa
# Processing Record 11 of Set 3 | dianopolis
# City not found. Skipping...
# Processing Record 12 of Set 3 | chernyshevskiy
# Processing Record 13 of Set 3 | faanui
# Processing Record 14 of Set 3 | souillac
# Processing Record 15 of Set 3 | kamina
# Processing Record 16 of Set 3 | gorontalo
# Processing Record 17 of Set 3 | esperance
# Processing Record 18 of Set 3 | pevek
# Processing Record 19 of Set 3 | kavaratti
# Processing Record 20 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 21 of Set 3 | ostersund
# Processing Record 22 of Set 3 | xocali
# Processing Record 23 of Set 3 | kawalu
# Processing Record 24 of Set 3 | sinnamary
# Processing Record 25 of Set 3 | goundam
# Processing Record 26 of Set 3 | brownsville
# Processing Record 27 of Set 3 | huangchuan
# Processing Record 28 of Set 3 | nikolskoye
# Processing Record 29 of Set 3 | ribeira grande
# Processing Record 30 of Set 3 | burica
# City not found. Skipping...
# Processing Record 31 of Set 3 | panguna
# Processing Record 32 of Set 3 | new norfolk
# Processing Record 33 of Set 3 | agadez
# Processing Record 34 of Set 3 | birin
# Processing Record 35 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 36 of Set 3 | tuatapere
# Processing Record 37 of Set 3 | madimba
# Processing Record 38 of Set 3 | samarai
# Processing Record 39 of Set 3 | kaitangata
# Processing Record 40 of Set 3 | corn island
# Processing Record 41 of Set 3 | warri
# Processing Record 42 of Set 3 | nushki
# Processing Record 43 of Set 3 | oktyabrskiy
# Processing Record 44 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 45 of Set 3 | gobabis
# Processing Record 46 of Set 3 | axim
# Processing Record 47 of Set 3 | bandiagara
# Processing Record 48 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 49 of Set 3 | fare
# Processing Record 50 of Set 3 | labutta
# City not found. Skipping...
# Processing Record 1 of Set 4 | goudomp
# City not found. Skipping...
# Processing Record 2 of Set 4 | touros
# Processing Record 3 of Set 4 | ijaki
# City not found. Skipping...
# Processing Record 4 of Set 4 | yumen
# Processing Record 5 of Set 4 | severo-kurilsk
# Processing Record 6 of Set 4 | saint anthony
# Processing Record 7 of Set 4 | bredasdorp
# Processing Record 8 of Set 4 | mayo
# Processing Record 9 of Set 4 | ravar
# Processing Record 10 of Set 4 | cheney
# Processing Record 11 of Set 4 | zemio
# Processing Record 12 of Set 4 | muros
# Processing Record 13 of Set 4 | barrow
# Processing Record 14 of Set 4 | clyde river
# Processing Record 15 of Set 4 | bathsheba
# Processing Record 16 of Set 4 | kirsanov
# Processing Record 17 of Set 4 | kupang
# Processing Record 18 of Set 4 | meyungs
# City not found. Skipping...
# Processing Record 19 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 20 of Set 4 | vostok
# Processing Record 21 of Set 4 | tura
# Processing Record 22 of Set 4 | luzhou
# Processing Record 23 of Set 4 | iqaluit
# Processing Record 24 of Set 4 | aswan
# Processing Record 25 of Set 4 | carnarvon
# Processing Record 26 of Set 4 | kachiry
# Processing Record 27 of Set 4 | nemocon
# Processing Record 28 of Set 4 | katsuura
# Processing Record 29 of Set 4 | caravelas
# Processing Record 30 of Set 4 | port elizabeth
# Processing Record 31 of Set 4 | hukuntsi
# Processing Record 32 of Set 4 | fevralsk
# City not found. Skipping...
# Processing Record 33 of Set 4 | dryden
# Processing Record 34 of Set 4 | moshi
# Processing Record 35 of Set 4 | chokurdakh
# Processing Record 36 of Set 4 | upernavik
# Processing Record 37 of Set 4 | saint-francois
# Processing Record 38 of Set 4 | airai
# Processing Record 39 of Set 4 | mattru
# Processing Record 40 of Set 4 | mayumba
# Processing Record 41 of Set 4 | mackenzie
# Processing Record 42 of Set 4 | camacha
# Processing Record 43 of Set 4 | saint-pierre
# Processing Record 44 of Set 4 | ponta delgada
# Processing Record 45 of Set 4 | tasiilaq
# Processing Record 46 of Set 4 | izumo
# Processing Record 47 of Set 4 | shiyan
# Processing Record 48 of Set 4 | emerald
# Processing Record 49 of Set 4 | coquimbo
# Processing Record 50 of Set 4 | anadyr
# Processing Record 1 of Set 5 | lasa
# Processing Record 2 of Set 5 | vila franca do campo
# Processing Record 3 of Set 5 | marienburg
# Processing Record 4 of Set 5 | haines junction
# Processing Record 5 of Set 5 | srednekolymsk
# Processing Record 6 of Set 5 | mezen
# Processing Record 7 of Set 5 | jewar
# Processing Record 8 of Set 5 | karimganj
# Processing Record 9 of Set 5 | cabedelo
# Processing Record 10 of Set 5 | pingliang
# Processing Record 11 of Set 5 | torbay
# Processing Record 12 of Set 5 | avera
# Processing Record 13 of Set 5 | cidreira
# Processing Record 14 of Set 5 | lata
# Processing Record 15 of Set 5 | kishapu
# Processing Record 16 of Set 5 | hirara
# Processing Record 17 of Set 5 | vardo
# Processing Record 18 of Set 5 | kraskino
# Processing Record 19 of Set 5 | palu
# Processing Record 20 of Set 5 | zhangjiakou
# Processing Record 21 of Set 5 | oga
# Processing Record 22 of Set 5 | brigantine
# Processing Record 23 of Set 5 | mocajuba
# Processing Record 24 of Set 5 | antalaha
# Processing Record 25 of Set 5 | novo aripuana
# Processing Record 26 of Set 5 | zhigansk
# Processing Record 27 of Set 5 | boralday
# Processing Record 28 of Set 5 | hamilton
# Processing Record 29 of Set 5 | auki
# Processing Record 30 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 31 of Set 5 | kayerkan
# Processing Record 32 of Set 5 | lagoa
# Processing Record 33 of Set 5 | port lincoln
# Processing Record 34 of Set 5 | tabiauea
# City not found. Skipping...
# Processing Record 35 of Set 5 | olafsvik
# Processing Record 36 of Set 5 | cayenne
# Processing Record 37 of Set 5 | murdochville
# Processing Record 38 of Set 5 | high level
# Processing Record 39 of Set 5 | faya
# Processing Record 40 of Set 5 | saint james
# Processing Record 41 of Set 5 | erdenet
# Processing Record 42 of Set 5 | iranshahr
# Processing Record 43 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 44 of Set 5 | fortuna
# Processing Record 45 of Set 5 | quzhou
# Processing Record 46 of Set 5 | adrar
# Processing Record 47 of Set 5 | farafangana
# Processing Record 48 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 49 of Set 5 | dinajpur
# Processing Record 50 of Set 5 | port macquarie
# Processing Record 1 of Set 6 | tuggurt
# City not found. Skipping...
# Processing Record 2 of Set 6 | dengfeng
# Processing Record 3 of Set 6 | kawambwa
# Processing Record 4 of Set 6 | abeche
# Processing Record 5 of Set 6 | rundu
# Processing Record 6 of Set 6 | ahipara
# Processing Record 7 of Set 6 | goderich
# Processing Record 8 of Set 6 | machiques
# Processing Record 9 of Set 6 | cockburn town
# Processing Record 10 of Set 6 | santa rosa
# Processing Record 11 of Set 6 | dunedin
# Processing Record 12 of Set 6 | moen
# Processing Record 13 of Set 6 | bayir
# Processing Record 14 of Set 6 | bandarbeyla
# Processing Record 15 of Set 6 | bucerias
# Processing Record 16 of Set 6 | grindavik
# Processing Record 17 of Set 6 | tagusao
# Processing Record 18 of Set 6 | taoudenni
# Processing Record 19 of Set 6 | balclutha
# Processing Record 20 of Set 6 | thompson
# Processing Record 21 of Set 6 | roma
# Processing Record 22 of Set 6 | nome
# Processing Record 23 of Set 6 | nola
# Processing Record 24 of Set 6 | ambon
# Processing Record 25 of Set 6 | constitucion
# Processing Record 26 of Set 6 | bilma
# Processing Record 27 of Set 6 | bani walid
# Processing Record 28 of Set 6 | dhule
# Processing Record 29 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 30 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 31 of Set 6 | mouzakion
# City not found. Skipping...
# Processing Record 32 of Set 6 | hambantota
# Processing Record 33 of Set 6 | santa vitoria do palmar
# Processing Record 34 of Set 6 | tabuk
# Processing Record 35 of Set 6 | san patricio
# Processing Record 36 of Set 6 | sioux lookout
# Processing Record 37 of Set 6 | kanigoro
# Processing Record 38 of Set 6 | kushima
# Processing Record 39 of Set 6 | midlothian
# Processing Record 40 of Set 6 | dabeiba
# Processing Record 41 of Set 6 | labuhan
# Processing Record 42 of Set 6 | broome
# Processing Record 43 of Set 6 | ahmadpur east
# Processing Record 44 of Set 6 | lorengau
# Processing Record 45 of Set 6 | mehamn
# Processing Record 46 of Set 6 | tomatlan
# Processing Record 47 of Set 6 | izvestkovyy
# Processing Record 48 of Set 6 | enshi
# Processing Record 49 of Set 6 | eidfjord
# Processing Record 50 of Set 6 | havelock
# Processing Record 1 of Set 7 | lincoln
# Processing Record 2 of Set 7 | buala
# Processing Record 3 of Set 7 | naliya
# Processing Record 4 of Set 7 | abay
# Processing Record 5 of Set 7 | kaeo
# Processing Record 6 of Set 7 | maldonado
# Processing Record 7 of Set 7 | northam
# Processing Record 8 of Set 7 | nouakchott
# Processing Record 9 of Set 7 | one hundred mile house
# City not found. Skipping...
# Processing Record 10 of Set 7 | lompoc
# Processing Record 11 of Set 7 | port blair
# Processing Record 12 of Set 7 | saldanha
# Processing Record 13 of Set 7 | susangerd
# Processing Record 14 of Set 7 | carutapera
# Processing Record 15 of Set 7 | geraldton
# Processing Record 16 of Set 7 | lavrentiya
# Processing Record 17 of Set 7 | lewistown
# Processing Record 18 of Set 7 | baykit
# Processing Record 19 of Set 7 | nemuro
# Processing Record 20 of Set 7 | lusambo
# Processing Record 21 of Set 7 | ushtobe
# Processing Record 22 of Set 7 | isangel
# Processing Record 23 of Set 7 | kharan
# Processing Record 24 of Set 7 | kyra
# Processing Record 25 of Set 7 | kruisfontein
# Processing Record 26 of Set 7 | ambanja
# Processing Record 27 of Set 7 | klaksvik
# Processing Record 28 of Set 7 | fayaoue
# Processing Record 29 of Set 7 | zabol
# Processing Record 30 of Set 7 | kulhudhuffushi
# Processing Record 31 of Set 7 | namibe
# Processing Record 32 of Set 7 | naples
# Processing Record 33 of Set 7 | sitka
# Processing Record 34 of Set 7 | longyearbyen
# Processing Record 35 of Set 7 | eufaula
# Processing Record 36 of Set 7 | gumdag
# Processing Record 37 of Set 7 | aklavik
# Processing Record 38 of Set 7 | tiksi
# Processing Record 39 of Set 7 | bulungu
# Processing Record 40 of Set 7 | strelka
# Processing Record 41 of Set 7 | jurado
# Processing Record 42 of Set 7 | usinsk
# Processing Record 43 of Set 7 | maragogi
# Processing Record 44 of Set 7 | luanda
# Processing Record 45 of Set 7 | port hardy
# Processing Record 46 of Set 7 | vanavara
# Processing Record 47 of Set 7 | nsanje
# Processing Record 48 of Set 7 | marathon
# Processing Record 49 of Set 7 | acapulco
# Processing Record 50 of Set 7 | kailua
# Processing Record 1 of Set 8 | salalah
# Processing Record 2 of Set 8 | grand forks
# Processing Record 3 of Set 8 | huinan
# Processing Record 4 of Set 8 | rorvik
# Processing Record 5 of Set 8 | hualmay
# Processing Record 6 of Set 8 | tarudant
# City not found. Skipping...
# Processing Record 7 of Set 8 | piranshahr
# Processing Record 8 of Set 8 | hwange
# Processing Record 9 of Set 8 | ladario
# Processing Record 10 of Set 8 | russell
# Processing Record 11 of Set 8 | dandong
# Processing Record 12 of Set 8 | catia la mar
# Processing Record 13 of Set 8 | kuressaare
# Processing Record 14 of Set 8 | floro
# Processing Record 15 of Set 8 | shuyskoye
# Processing Record 16 of Set 8 | tingi
# Processing Record 17 of Set 8 | oistins
# Processing Record 18 of Set 8 | pacifica
# Processing Record 19 of Set 8 | yar-sale
# Processing Record 20 of Set 8 | cherskiy
# Processing Record 21 of Set 8 | castel volturno
# Processing Record 22 of Set 8 | nuuk
# Processing Record 23 of Set 8 | sao joao da barra
# Processing Record 24 of Set 8 | saint-joseph
# Processing Record 25 of Set 8 | manzil tamim
# City not found. Skipping...
# Processing Record 26 of Set 8 | udachnyy
# Processing Record 27 of Set 8 | taburi
# City not found. Skipping...
# Processing Record 28 of Set 8 | wanning
# Processing Record 29 of Set 8 | aberdeen
# Processing Record 30 of Set 8 | umm lajj
# Processing Record 31 of Set 8 | carman
# Processing Record 32 of Set 8 | san quintin
# Processing Record 33 of Set 8 | mhlume
# Processing Record 34 of Set 8 | belaya gora
# Processing Record 35 of Set 8 | somerset east
# Processing Record 36 of Set 8 | chagda
# City not found. Skipping...
# Processing Record 37 of Set 8 | sao felix do xingu
# Processing Record 38 of Set 8 | mulbagal
# Processing Record 39 of Set 8 | kavieng
# Processing Record 40 of Set 8 | kargopol
# Processing Record 41 of Set 8 | alibag
# Processing Record 42 of Set 8 | freeport
# Processing Record 43 of Set 8 | biggar
# Processing Record 44 of Set 8 | pitsunda
# Processing Record 45 of Set 8 | filadelfia
# Processing Record 46 of Set 8 | sakakah
# Processing Record 47 of Set 8 | belyy yar
# Processing Record 48 of Set 8 | toba
# Processing Record 49 of Set 8 | pochutla
# Processing Record 50 of Set 8 | meulaboh
# Processing Record 1 of Set 9 | kijang
# Processing Record 2 of Set 9 | sur
# Processing Record 3 of Set 9 | calvinia
# Processing Record 4 of Set 9 | bonavista
# Processing Record 5 of Set 9 | vigrestad
# Processing Record 6 of Set 9 | xichang
# Processing Record 7 of Set 9 | yenagoa
# Processing Record 8 of Set 9 | vavatenina
# Processing Record 9 of Set 9 | alice springs
# Processing Record 10 of Set 9 | garowe
# Processing Record 11 of Set 9 | ambulu
# Processing Record 12 of Set 9 | iberia
# Processing Record 13 of Set 9 | bandundu
# Processing Record 14 of Set 9 | vila velha
# Processing Record 15 of Set 9 | berbera
# Processing Record 16 of Set 9 | mgandu
# Processing Record 17 of Set 9 | shelburne
# Processing Record 18 of Set 9 | tasbuget
# City not found. Skipping...
# Processing Record 19 of Set 9 | malwan
# City not found. Skipping...
# Processing Record 20 of Set 9 | matagami
# Processing Record 21 of Set 9 | laguna
# Processing Record 22 of Set 9 | pontianak
# Processing Record 23 of Set 9 | ust-maya
# Processing Record 24 of Set 9 | iralaya
# Processing Record 25 of Set 9 | comodoro rivadavia
# Processing Record 26 of Set 9 | pathein
# Processing Record 27 of Set 9 | ilulissat
# Processing Record 28 of Set 9 | fukue
# Processing Record 29 of Set 9 | tomball
# Processing Record 30 of Set 9 | ormara
# Processing Record 31 of Set 9 | amapa
# Processing Record 32 of Set 9 | kahului
# Processing Record 33 of Set 9 | szczytno
# Processing Record 34 of Set 9 | ossora
# Processing Record 35 of Set 9 | kashi
# Processing Record 36 of Set 9 | oranjemund
# Processing Record 37 of Set 9 | paita
# Processing Record 38 of Set 9 | rawannawi
# City not found. Skipping...
# Processing Record 39 of Set 9 | champasak
# Processing Record 40 of Set 9 | cuajinicuilapa
# Processing Record 41 of Set 9 | a coruna
# Processing Record 42 of Set 9 | dinghai
# Processing Record 43 of Set 9 | nizhniy tsasuchey
# Processing Record 44 of Set 9 | salisbury
# Processing Record 45 of Set 9 | aragyukh
# City not found. Skipping...
# Processing Record 46 of Set 9 | mount darwin
# Processing Record 47 of Set 9 | san juan
# Processing Record 48 of Set 9 | grand centre
# City not found. Skipping...
# Processing Record 49 of Set 9 | sorong
# Processing Record 50 of Set 9 | heishan
# Processing Record 1 of Set 10 | paka
# Processing Record 2 of Set 10 | najran
# Processing Record 3 of Set 10 | zhigalovo
# Processing Record 4 of Set 10 | warqla
# City not found. Skipping...
# Processing Record 5 of Set 10 | alindao
# Processing Record 6 of Set 10 | neuquen
# Processing Record 7 of Set 10 | icatu
# Processing Record 8 of Set 10 | gunjur
# Processing Record 9 of Set 10 | bonthe
# Processing Record 10 of Set 10 | orlik
# Processing Record 11 of Set 10 | bukachacha
# Processing Record 12 of Set 10 | uaua
# Processing Record 13 of Set 10 | da nang
# Processing Record 14 of Set 10 | anar darreh
# City not found. Skipping...
# Processing Record 15 of Set 10 | tres palos
# Processing Record 16 of Set 10 | ayan
# Processing Record 17 of Set 10 | sembe
# Processing Record 18 of Set 10 | abha
# Processing Record 19 of Set 10 | kiama
# Processing Record 20 of Set 10 | pinawa
# Processing Record 21 of Set 10 | minab
# Processing Record 22 of Set 10 | makakilo city
# Processing Record 23 of Set 10 | hofn
# Processing Record 24 of Set 10 | killybegs
# Processing Record 25 of Set 10 | pangoa
# Processing Record 26 of Set 10 | xai-xai
# Processing Record 27 of Set 10 | harper
# Processing Record 28 of Set 10 | rocha
# Processing Record 29 of Set 10 | asosa
# Processing Record 30 of Set 10 | buenos aires
# Processing Record 31 of Set 10 | jackson
# Processing Record 32 of Set 10 | sokoni
# Processing Record 33 of Set 10 | port moresby
# Processing Record 34 of Set 10 | ternate
# Processing Record 35 of Set 10 | eureka
# Processing Record 36 of Set 10 | dossor
# Processing Record 37 of Set 10 | kharitonovo
# Processing Record 38 of Set 10 | westpunt
# City not found. Skipping...
# Processing Record 39 of Set 10 | nisia floresta
# Processing Record 40 of Set 10 | lerwick
# Processing Record 41 of Set 10 | half moon bay
# Processing Record 42 of Set 10 | vermilion
# Processing Record 43 of Set 10 | sisimiut
# Processing Record 44 of Set 10 | luwuk
# Processing Record 45 of Set 10 | yialos
# City not found. Skipping...
# Processing Record 46 of Set 10 | fairbanks
# Processing Record 47 of Set 10 | aktash
# Processing Record 48 of Set 10 | vanimo
# Processing Record 49 of Set 10 | tolyatti
# Processing Record 50 of Set 10 | bullhead city
# Processing Record 1 of Set 11 | thinadhoo
# Processing Record 2 of Set 11 | gloucester
# Processing Record 3 of Set 11 | talnakh
# Processing Record 4 of Set 11 | rincon
# Processing Record 5 of Set 11 | monticello
# Processing Record 6 of Set 11 | bartica
# Processing Record 7 of Set 11 | port said
# Processing Record 8 of Set 11 | kosonsoy
# Processing Record 9 of Set 11 | jawhar
# Processing Record 10 of Set 11 | padang
# Processing Record 11 of Set 11 | liverpool
# Processing Record 12 of Set 11 | bukoba
# Processing Record 13 of Set 11 | annau
# Processing Record 14 of Set 11 | rio gallegos
# Processing Record 15 of Set 11 | san pedro de macoris
# Processing Record 16 of Set 11 | nguiu
# City not found. Skipping...
# Processing Record 17 of Set 11 | kattivakkam
# Processing Record 18 of Set 11 | race
# Processing Record 19 of Set 11 | hami
# Processing Record 20 of Set 11 | yeppoon
# Processing Record 21 of Set 11 | viedma
# Processing Record 22 of Set 11 | alofi
# Processing Record 23 of Set 11 | noyabrsk
# Processing Record 24 of Set 11 | krasnoselkup
# Processing Record 25 of Set 11 | la ronge
# Processing Record 26 of Set 11 | portland
# Processing Record 27 of Set 11 | gladstone
# Processing Record 28 of Set 11 | juegang
# Processing Record 29 of Set 11 | turayf
# Processing Record 30 of Set 11 | kuche
# City not found. Skipping...
# Processing Record 31 of Set 11 | silifke
# Processing Record 32 of Set 11 | bereda
# Processing Record 33 of Set 11 | shitanjing
# Processing Record 34 of Set 11 | hendrina
# Processing Record 35 of Set 11 | tulum
# Processing Record 36 of Set 11 | vaitape
# Processing Record 37 of Set 11 | diplo
# Processing Record 38 of Set 11 | pedernales
# Processing Record 39 of Set 11 | port-gentil
# Processing Record 40 of Set 11 | owasso
# Processing Record 41 of Set 11 | lakes entrance
# Processing Record 42 of Set 11 | bakel
# Processing Record 43 of Set 11 | moshenskoye
# Processing Record 44 of Set 11 | arica
# Processing Record 45 of Set 11 | bac lieu
# Processing Record 46 of Set 11 | vernon
# Processing Record 47 of Set 11 | lebu
# Processing Record 48 of Set 11 | kieta
# Processing Record 49 of Set 11 | arsk
# Processing Record 50 of Set 11 | karaul
# City not found. Skipping...
# Processing Record 1 of Set 12 | luganville
# Processing Record 2 of Set 12 | stamsund
# City not found. Skipping...
# Processing Record 3 of Set 12 | ulaangom
# Processing Record 4 of Set 12 | artyk
# City not found. Skipping...
# Processing Record 5 of Set 12 | east london
# Processing Record 6 of Set 12 | grootfontein
# Processing Record 7 of Set 12 | svetlaya
# Processing Record 8 of Set 12 | the pas
# Processing Record 9 of Set 12 | nazret
# Processing Record 10 of Set 12 | porto belo
# Processing Record 11 of Set 12 | aljezur
# Processing Record 12 of Set 12 | campbellton
# Processing Record 13 of Set 12 | hovd
# Processing Record 14 of Set 12 | quatre cocos
# Processing Record 15 of Set 12 | deputatskiy
# Processing Record 16 of Set 12 | santiago del estero
# Processing Record 17 of Set 12 | zlobin
# Processing Record 18 of Set 12 | bakaly
# Processing Record 19 of Set 12 | onega
# Processing Record 20 of Set 12 | luderitz
# Processing Record 21 of Set 12 | asau
# Processing Record 22 of Set 12 | college
# Processing Record 23 of Set 12 | dolbeau
# City not found. Skipping...
# Processing Record 24 of Set 12 | xingyi
# Processing Record 25 of Set 12 | mjolby
# Processing Record 26 of Set 12 | richards bay
# Processing Record 27 of Set 12 | kuusamo
# Processing Record 28 of Set 12 | roros
# Processing Record 29 of Set 12 | bairiki
# Processing Record 30 of Set 12 | lodwar
# Processing Record 31 of Set 12 | barvikha
# Processing Record 32 of Set 12 | ouro branco
# Processing Record 33 of Set 12 | darnah
# Processing Record 34 of Set 12 | gilgit
# Processing Record 35 of Set 12 | benha
# City not found. Skipping...
# Processing Record 36 of Set 12 | marawi
# Processing Record 37 of Set 12 | verkhnyaya inta
# Processing Record 38 of Set 12 | moerai
# Processing Record 39 of Set 12 | quelimane
# Processing Record 40 of Set 12 | kamenskoye
# City not found. Skipping...
# Processing Record 41 of Set 12 | santa isabel
# Processing Record 42 of Set 12 | port augusta
# Processing Record 43 of Set 12 | morondava
# Processing Record 44 of Set 12 | dongying
# Processing Record 45 of Set 12 | pecos
# Processing Record 46 of Set 12 | ixtapa
# Processing Record 47 of Set 12 | iquique
# Processing Record 48 of Set 12 | kloulklubed
# Processing Record 49 of Set 12 | benin
# Processing Record 50 of Set 12 | nautla
# Processing Record 1 of Set 13 | peniche
# Processing Record 2 of Set 13 | copiapo
# Processing Record 3 of Set 13 | kachug
# Processing Record 4 of Set 13 | ust-kulom
# Processing Record 5 of Set 13 | sambava
# Processing Record 6 of Set 13 | atambua
# Processing Record 7 of Set 13 | sal rei
# Processing Record 8 of Set 13 | coihaique
# Processing Record 9 of Set 13 | bowen
# Processing Record 10 of Set 13 | san cristobal
# Processing Record 11 of Set 13 | ganzhou
# Processing Record 12 of Set 13 | liwale
# Processing Record 13 of Set 13 | havre-saint-pierre
# Processing Record 14 of Set 13 | pali
# Processing Record 15 of Set 13 | canaries
# Processing Record 16 of Set 13 | makhinjauri
# Processing Record 17 of Set 13 | thilogne
# City not found. Skipping...
# Processing Record 18 of Set 13 | greenfield
# Processing Record 19 of Set 13 | muktagachha
# City not found. Skipping...
# Processing Record 20 of Set 13 | pinerovka
# Processing Record 21 of Set 13 | sattahip
# Processing Record 22 of Set 13 | blagoveshchenka
# Processing Record 23 of Set 13 | mpika
# Processing Record 24 of Set 13 | aloleng
# Processing Record 25 of Set 13 | marondera
# Processing Record 26 of Set 13 | warwick
# Processing Record 27 of Set 13 | luoyang
# Processing Record 28 of Set 13 | bintulu
# Processing Record 29 of Set 13 | ugoofaaru
# Processing Record 30 of Set 13 | pangnirtung
# Processing Record 31 of Set 13 | verkhnevilyuysk
# Processing Record 32 of Set 13 | kigoma
# Processing Record 33 of Set 13 | livani
# Processing Record 34 of Set 13 | gunzenhausen
# Processing Record 35 of Set 13 | shihezi
# Processing Record 36 of Set 13 | osoyoos
# Processing Record 37 of Set 13 | dedza
# Processing Record 38 of Set 13 | bandarban
# Processing Record 39 of Set 13 | willowmore
# Processing Record 40 of Set 13 | san jose
# Processing Record 41 of Set 13 | pareora
# Processing Record 42 of Set 13 | poya
# Processing Record 43 of Set 13 | tansen
# Processing Record 44 of Set 13 | dzilam gonzalez
# Processing Record 45 of Set 13 | belmonte
# Processing Record 46 of Set 13 | abiy adi
# City not found. Skipping...
# Processing Record 47 of Set 13 | aripuana
# Processing Record 48 of Set 13 | elk
# Processing Record 49 of Set 13 | dubai
# Processing Record 50 of Set 13 | telimele
# Processing Record 1 of Set 14 | praia
# Processing Record 2 of Set 14 | ostrovnoy
# Processing Record 3 of Set 14 | faribault
# Processing Record 4 of Set 14 | borazjan
# Processing Record 5 of Set 14 | temiscaming
# Processing Record 6 of Set 14 | eldikan
# City not found. Skipping...
# Processing Record 7 of Set 14 | sorland
# Processing Record 8 of Set 14 | kosh-agach
# Processing Record 9 of Set 14 | jequie
# Processing Record 10 of Set 14 | bangangte
# Processing Record 11 of Set 14 | opuwo
# Processing Record 12 of Set 14 | quincy
# Processing Record 13 of Set 14 | severnyy
# Processing Record 14 of Set 14 | shahr-e kord
# Processing Record 15 of Set 14 | culebra
# Processing Record 16 of Set 14 | vao
# Processing Record 17 of Set 14 | san matias
# Processing Record 18 of Set 14 | arlit
# Processing Record 19 of Set 14 | amahai
# Processing Record 20 of Set 14 | manggar
# Processing Record 21 of Set 14 | ambilobe
# Processing Record 22 of Set 14 | toliary
# City not found. Skipping...
# Processing Record 23 of Set 14 | waddan
# Processing Record 24 of Set 14 | wulanhaote
# City not found. Skipping...
# Processing Record 25 of Set 14 | ahumada
# City not found. Skipping...
# Processing Record 26 of Set 14 | chuchkovo
# Processing Record 27 of Set 14 | batagay-alyta
# Processing Record 28 of Set 14 | primorka
# Processing Record 29 of Set 14 | troitskaya
# Processing Record 30 of Set 14 | cortes
# Processing Record 31 of Set 14 | grand-lahou
# Processing Record 32 of Set 14 | qeshm
# Processing Record 33 of Set 14 | badhni kalan
# Processing Record 34 of Set 14 | tulun
# Processing Record 35 of Set 14 | boende
# Processing Record 36 of Set 14 | montrose
# Processing Record 37 of Set 14 | urengoy
# Processing Record 38 of Set 14 | chakwal
# Processing Record 39 of Set 14 | alta floresta
# Processing Record 40 of Set 14 | batemans bay
# Processing Record 41 of Set 14 | ballina
# Processing Record 42 of Set 14 | tautira
# Processing Record 43 of Set 14 | dagumba-an
# Processing Record 44 of Set 14 | ngukurr
# City not found. Skipping...
# Processing Record 45 of Set 14 | yermakovskoye
# Processing Record 46 of Set 14 | ewo
# Processing Record 47 of Set 14 | pauini
# Processing Record 48 of Set 14 | dakar
# Processing Record 49 of Set 14 | santo antonio do leverger
# Processing Record 50 of Set 14 | jumla
# Processing Record 1 of Set 15 | bilibino
# Processing Record 2 of Set 15 | vadinsk
# Processing Record 3 of Set 15 | mwanza
# Processing Record 4 of Set 15 | semirom
# Processing Record 5 of Set 15 | mogadishu
# Processing Record 6 of Set 15 | ketchikan
# Processing Record 7 of Set 15 | salinas
# Processing Record 8 of Set 15 | zanesville
# Processing Record 9 of Set 15 | tazovskiy
# Processing Record 10 of Set 15 | jinchang
# Processing Record 11 of Set 15 | sainte-marie
# Processing Record 12 of Set 15 | talcahuano
# Processing Record 13 of Set 15 | puro
# Processing Record 14 of Set 15 | rogaska slatina
# Processing Record 15 of Set 15 | slonim
# Processing Record 16 of Set 15 | suwalki
# Processing Record 17 of Set 15 | polunochnoye
# Processing Record 18 of Set 15 | anloga
# Processing Record 19 of Set 15 | raudeberg
# Processing Record 20 of Set 15 | itanhem
# Processing Record 21 of Set 15 | barra
# Processing Record 22 of Set 15 | strezhevoy
# Processing Record 23 of Set 15 | ruteng
# Processing Record 24 of Set 15 | vidim
# Processing Record 25 of Set 15 | naze
# Processing Record 26 of Set 15 | juneau
# Processing Record 27 of Set 15 | malanje
# Processing Record 28 of Set 15 | terrace
# Processing Record 29 of Set 15 | corcoran
# Processing Record 30 of Set 15 | anshun
# Processing Record 31 of Set 15 | pokhara
# Processing Record 32 of Set 15 | darhan
# Processing Record 33 of Set 15 | poum
# Processing Record 34 of Set 15 | krasnyy yar
# Processing Record 35 of Set 15 | aragats
# Processing Record 36 of Set 15 | emirdag
# Processing Record 37 of Set 15 | woodward
# Processing Record 38 of Set 15 | kozyatyn
# Processing Record 39 of Set 15 | dingle
# Processing Record 40 of Set 15 | gibara
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0            Hilo      US  19.7297 -155.0900     61.00        67           1
# 1     Henties Bay      NA -22.1160   14.2845     66.99        83          17
# 2        Bengkulu      ID  -3.8004  102.2655     76.86        85          78
# 3          Jining      CN  35.4050  116.5814     49.68        44          10
# 4          Albany      US  42.6001  -73.9662     35.01        39          76
# 5  Saint-Philippe      RE -21.3585   55.7679     84.20        70          75
# 6           Bluff      NZ -46.6000  168.3333     54.27        86           9
# 7          Avarua      CK -21.2078 -159.7750     77.00        88          20
# 8  Saint-Augustin      CA  51.2260  -58.6502     32.14        98         100
# 9          Marzuq      YE  14.4000   46.4667     62.28        67           0
#
#    Wind Speed Current Description
# 0        6.91           clear sky
# 1        3.00          few clouds
# 2        6.55       broken clouds
# 3        5.99           clear sky
# 4        4.00          light snow
# 5        6.91          light rain
# 6        1.45           clear sky
# 7        3.44          light rain
# 8       11.83     overcast clouds
# 9        8.41           clear sky

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
